# %%
import os
import librosa
import IPython.display as ipd

# %%
import main1

# %%
main1.main()
# Out:
# Performing inference..
# 33810 33810
# Denoising: p232_411.wav
# 100%|██████████| 5/5 [00:00<00:00,  8.72it/s]
# 28818 28818
# 27672 27672
# rms_noise_out 0.004354414861115025 rms_noise_in 0.012830754
# 27833 27833
# Denoising: p232_414.wav
# 100%|██████████| 4/4 [00:00<00:00, 14.14it/s]
# 22414 22414
# 21695 21695
# rms_noise_out 0.01479474523576058 rms_noise_in 0.08224559
#  40%|████      | 2/5 [00:00<00:00, 12.46it/s]
# 36976 36976
# Denoising: p257_433.wav
# 100%|██████████| 5/5 [00:00<00:00, 12.41it/s]
# 32020 32020
# 30838 30838
# rms_noise_out 0.005910327477876121 rms_noise_in 0.019461682
#  40%|████      | 2/5 [00:00<00:00, 12.54it/s]
# 33342 33342
# Denoising: p257_434.wav
# 100%|██████████| 5/5 [00:00<00:00, 14.60it/s]
# 27217 27217
# 27204 27204
# rms_noise_out 0.007151466141033863 rms_noise_in 0.059495468
#  40%|████      | 2/5 [00:00<00:00, 12.52it/s]
# 36310 36310
# Denoising: p232_413.wav
# 100%|██████████| 5/5 [00:00<00:00, 13.33it/s]
# 30419 30419
# 30172 30172
# ...

# %%
filelist = os.listdir('./data/NSDTSEA/samples/samples_9')

# %%
filelist_denoised = sorted([file for file in filelist if file.find('denoised')!=-1])
filelist_clean = sorted([file for file in filelist if file.find('clean')!=-1])
filelist_noisy = sorted([file for file in filelist if file.find('noisy')!=-1])
filelist_noise = sorted([file for file in filelist if file.find('noise.wav')!=-1])

# %%
srn = 6
sample_no = 9

# %%
print(filelist_denoised[srn], filelist_clean[srn], filelist_noisy[srn], filelist_noise[srn])
# Out:
# p257_431_denoised_17dB.wav p257_431_clean.wav p257_431_noisy_7dB.wav p257_431_noise.wav

# %%
ipd.Audio(os.path.join(f'./data/NSDTSEA/samples/samples_{sample_no}', filelist_clean[srn]))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(os.path.join(f'./data/NSDTSEA/samples/samples_{sample_no}', filelist_noisy[srn]))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(os.path.join(f'./data/NSDTSEA/samples/samples_{sample_no}', filelist_denoised[srn]))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(os.path.join(f'./data/NSDTSEA/samples/samples_{sample_no}', filelist_noise[srn]))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data_noisy, _ = librosa.load(os.path.join(f'./data/NSDTSEA/samples/samples_{sample_no}', filelist_noisy[srn]), sr = 16000)
data_noise, _ = librosa.load(os.path.join(f'./data/NSDTSEA/samples/samples_{sample_no}', filelist_noise[srn]), sr = 16000)

# %%
data_denoised = data_noisy - data_noise

# %%
ipd.Audio(data_denoised, rate = 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
